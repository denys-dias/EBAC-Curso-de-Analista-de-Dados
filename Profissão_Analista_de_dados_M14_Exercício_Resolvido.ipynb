# %% [markdown]
# <a href="https://colab.research.google.com/github/denys-dias/EBAC-Curso-de-Analista-de-Dados/blob/main/Profiss%C3%A3o_Analista_de_dados_M14_Exerc%C3%ADcio_Resolvido.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Visualização de Dados I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Pacote Seaborn;</li>
#   <li>Categorias: Gráficos de Barras e de Setores;</li>
#   <li>Tendências: Gráficos de Linha e de Área.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# Nestes exercícios, você deve decidir qual é o gráfico visto em aula que melhor visualiza uma base de dados. Após decidir, você deverá criar a visualização usando o conteúdo exposto durante a aula e adicionar um pequeno parágrafo sobre um insights que pode ser extraido do gráfico.

# %% [markdown]
# ## 1\. Preço do diamante por tipo de corte

# %%
import seaborn as sns

data = sns.load_dataset("diamonds")
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# gráfico do exercício 1

diamonds = sns.barplot(data=data, x="cut", y="price")
diamonds.set(title='Preço do diamante por tipo de corte', xlabel='Tipo de corte', ylabel='Preço');

# %% [markdown]
# **Insight do gráfico 1**: ...

# %% [markdown]
# Os diamantes com corte Premium apresentam os maiores preços

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Número de passageiros em dezembro por ano

# %%
import seaborn as sns

data = sns.load_dataset("flights")
data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights = data.query("month == 'Dec'")
flights.head()
# Out:
#     year month  passengers
# 11  1949   Dec         118
# 23  1950   Dec         140
# 35  1951   Dec         166
# 47  1952   Dec         194
# 59  1953   Dec         201

# %%
flights = sns.lineplot(data=flights, x="year", y="passengers")
flights.set(title='Passageiros em dezembro por ano', xlabel='Ano', ylabel='Passageiros');

# %% [markdown]
# **Insight do gráfico 2**: ...

# %% [markdown]
# O número de passegeiros em dezembro, por ano, aumenta ao longo to tempo.

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Numero de passageiros por mês entre 1949 e 1959

# %%
import seaborn as sns

data = sns.load_dataset("flights")
data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# gráfico do exercício 3

flights = data.query("1949 <= year < 1960")

with sns.axes_style('whitegrid'):

  grafico = sns.lineplot(data=flights, x="month", y="passengers", hue="year", palette="pastel")
  grafico.set(title='Passageiros por mês entre 1949 e 1959', xlabel='Mês', ylabel='Passageiros');

# %% [markdown]
# **Insight do gráfico 3**: ...

# %% [markdown]
# Os anos apresentam uma mesma tendência quanto ao número de passageiros ao mês. Janeiro, fevereiro, maio e novembro são meses de baixa. Já os meses de março, agosto e dezembro são meses de alta.

# %% [markdown]
# ---
